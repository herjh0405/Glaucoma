# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
import datetime as dt
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
df_sam2_ori = pd.read_csv('./data/want_data.csv')

# %%
df_sam2 = df_sam2_ori.sort_values(['PID', 'AGE']).copy()

# %%
want = df_sam2[['PID','AGE','Eye','Exam Date']+list(df_sam2.iloc[:,342:].columns)]

# %%
pd.to_datetime(want['Exam Date'])
# Out:
# 0     2010-11-19 10:32:01
# 1     2010-11-19 10:25:16
# 2     2011-11-11 08:45:17
# 3     2011-11-11 08:39:38
# 4     2012-10-31 14:58:08
#               ...
# 384   2005-02-10 17:30:07
# 385   2006-09-20 14:05:38
# 386   2006-09-20 13:58:34
# 387   2007-10-04 09:19:31
# 388   2007-10-04 09:09:12
# Name: Exam Date, Length: 389, dtype: datetime64[ns]

# %%
want['Exam Date'] = pd.to_datetime(want['Exam Date']).map(dt.datetime.toordinal)

# %%
want.groupby(['PID','Eye']).count()
# Out:
#          AGE  Exam Date  real_THV_1  real_THV_2  real_THV_3  real_THV_4  \
# PID Eye
# 2   OD     7          7           7           7           7           7
#     OS     7          7           7           7           7           7
# 9   OS     6          6           6           6           6           6
# 12  OD     7          7           7           7           7           7
#     OS     7          7           7           7           7           7
# 17  OD     5          5           5           5           5           5
#     OS     5          5           5           5           5           5
# 19  OD     8          8           8           8           8           8
#     OS     8          8           8           8           8           8
# 25  OD    13         13          13          13          13          13
#     OS    13         13          13          13          13          13
# 28  OD     4          4           4           4           4           4
# ...

# %%
X = want[(want['PID']==181)&(want['Eye']=='OS')]['Exam Date'].values.reshape(-1,1)
y = want['real_THV_1'].values

# %%
y
# Out:
# array([27, 25, 30, 30, 25, 28, 26, 29, 30, 31, 30, 31, 27, 27,  0,  0,  0,
#         0,  0,  2, 24, 15, 25, 17, 24,  9, 24,  5, 24,  4, 23,  0, 19,  0,
#        24, 26, 18, 23, 27, 24,  4, 20, 31, 31, 21, 18, 21,  6,  9, 15, 10,
#         1, 27, 29, 18,  9, 23, 22,  2, 20, 24, 24, 26, 22, 24, 21, 24, 25,
#        24, 21, 25, 22, 23, 23, 22, 22, 22, 25, 22, 25, 18, 25, 15, 24, 17,
#        11, 17,  8, 26, 11, 23, 19, 22, 23, 23, 25, 22, 19, 28, 26, 22, 23,
#        22, 28, 24, 24, 25, 24, 24, 24, 27, 22, 28, 28, 26, 28, 26, 26, 26,
#        28, 18, 22, 17, 18, 20, 19, 16, 21,  0,  8, 21, 16, 26, 28, 32, 34,
#        35, 30, 34, 33, 21, 26, 25, 22, 27, 27, 33, 27, 27, 27, 26, 27, 25,
#        31, 24,  0,  0,  0,  0, 26, 27,  0,  0,  0,  0,  0, 28, 24, 26, 22,
#         0, 25, 25, 20,  8, 23,  9, 24,  9, 24, 12, 24,  2, 10, 18, 27,  0,
#        13, 12, 11,  8,  7,  0, 22,  6, 13,  2, 13,  7, 21, 21, 18, 19, 14,
# ...

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tscv = TimeSeriesSplit(max_train_size = 4)

# %%
import numpy

# %%
np.sqrt
# Out:
# <ufunc 'sqrt'>

# %%
from sklearn.metrics import mean_squared_error
tscv = TimeSeriesSplit(n_splits = 4, max_train_size = 4)
rmse = []
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    
    
    line_fitter = LinearRegression()
    result = line_fitter.fit(X_train, y_train)
        
    predictions = result.predict(X_test)
    true_values = y_test
    rmse.append(np.sqrt(mean_squared_error(true_values, predictions)))
    
print("RMSE: {}".format(np.mean(rmse)))
# Out:
# RMSE: 15.547215276052633

# %%
y_test
# Out:
# array([25, 28, 26, 29], dtype=int64)

# %%
tscv = TimeSeriesSplit(n_splits = 4, max_train_size = 4)
rmse = []
for train_index, test_index in tscv.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
train_index
# Out:
# array([13, 14, 15, 16])

# %%
X
# Out:
# array([[735456],
#        [735207],
#        [735565],
#        [735914],
#        [735747],
#        [735998],
#        [736332],
#        [736759],
#        [733787],
#        [733864],
#        [735271],
#        [734211],
#        [736583],
#        [734598],
#        [734305],
#        [734270],
#        [736150],
#        [735779],
#        [736299],
#        [736465]], dtype=int64)

# %%
X_train
# Out:
# array([[734598],
#        [734305],
#        [734270],
#        [736150]], dtype=int64)

# %%
line_fitter = LinearRegression()
result = line_fitter.fit(X_train, y_train)

# %%
yhat = result.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
y_test
# Out:
# array([0, 0, 2], dtype=int64)

# %%
accuracy_score(y_test, yhat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-f46ef14ebac8> in <module>
# ----> 1 accuracy_score(y_test, yhat)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# --> 187     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     188     check_consistent_length(y_true, y_pred, sample_weight)
#     189     if y_type.startswith('multilabel'):
#
# ...
